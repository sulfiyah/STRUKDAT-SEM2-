# %% [markdown]
# **Struktur Tree berdasarkan identitas saya**

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

root = Node(15)
root.left = Node(6)
root.right = Node(42)
root.left.left = Node(30)
root.left.right = Node(6)

def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

print("Inorder Traversal:")
inorder(root)
# Out:
# Inorder Traversal:
# 30 6 6 15 42

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)
        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)
        return root

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.data, end=' ')
            self.inorder(node.right)

    def preorder(self, node):
        if node:
            print(node.data, end=' ')
            self.preorder(node.left)
            self.preorder(node.right)

    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.data, end=' ')

    def search(self, node, key):
        if node is None or node.data == key:
            return node
        if key < node.data:
            return self.search(node.left, key)
        return self.search(node.right, key)

daftar_angka = [42, 30, 6, 70, 65, 88, 4]
data_list = list(set(daftar_angka))

bst = BinarySearchTree()
root = None
for angka in data_list:
    root = bst.insert(root, angka)

print("Inorder Traversal:")
bst.inorder(root)
print("\nPreorder Traversal:")
bst.preorder(root)
print("\nPostorder Traversal:")
bst.postorder(root)

key = 42
result = bst.search(root, key)
if result:
    print(f"\nNode with value {key} found.")
else:
    print(f"\nNode with value {key} not found.")

key = 99
result = bst.search(root, key)
if result:
    print(f"\nNode with value {key} found.")
else:
    print(f"\nNode with value {key} not found.")
# Out:
# Inorder Traversal:
# 4 6 30 42 65 70 88
# Preorder Traversal:
# 65 4 6 42 30 70 88
# Postorder Traversal:
# 30 42 6 4 88 70 65
# Node with value 42 found.
#
# Node with value 99 not found.
