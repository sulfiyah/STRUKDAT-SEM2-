# %%
size = 10

treasure_map = ["_" for _ in range(size)]

print(f"selamat datang di Treasure Hunt! Peta memiliki {size} lokasi (0 hingga {size-1}).")
treasure_index = int(input(f"Masukan lokasi harta karun (0-{size-1}): "))
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentan yang benar.")
  treasure_index = int(input(f"Masukkan lokasi harta karun (0-{size-1}): "))

treasure_map[treasure_index] = "X"

def play_treasure_hunt():
  print("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak.")
  print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")
  while True:
    print ("\nPeta saat ini: ", ["_" for _ in range(size)])
    try:
      guess = int(input(f"Masukkan indeks tebakanmu (0-{size-1}): "))
    except ValueError:
      print("Masukkan angka yang valid.")
      continue

    if guess < 0 or guess >= size:
      print("Indeks tidak valid, pilih antara 0 hingga", size-1)
      continue

    if treasure_map[guess] == "X":
      print("Selamat! Kamu menemukan harta karun di lokasi:", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini. Coba lagi!")

  print("Terima kasih sudah bermain!")

play_treasure_hunt()
# Out:
# selamat datang di Treasure Hunt! Peta memiliki 10 lokasi (0 hingga 9).
# Masukan lokasi harta karun (0-9): 5
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0-9): 7
# Tidak ada harta di lokasi ini. Coba lagi!
#
# Peta saat ini:  ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan indeks tebakanmu (0-9): 5
# Selamat! Kamu menemukan harta karun di lokasi: 5
# Terima kasih sudah bermain!

# %% [markdown]
# # TREASURE HUNT (A)

# %%
print(f"Selamat datang di Treasure Hunt! ִֶָ𓂃 ࣪˖ ִֶָ🐇་༘࿐")
size = int(input(" ₊˚˖ Masukkan ukuran peta yang diinginkan ₊˚˖ "))

treasure_map = ["─୨ৎ─" for _ in range(size)]

print(f"⋆. 𐙚 ˚Peta memiliki {size} lokasi (0 hingga {size-1})⋆. 𐙚 ˚.")
treasure_index = int(input(f" ๋࣭ ⭑⚝ Masukkan lokasi harta karun (0-{size-1})๋࣭ ⭑⚝ "))
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentang yang benar⛇☃︎.")
  treasure_index = int(input(f"  ๋࣭ ⭑⚝ Masukkan lokasi harta karun (0-{size-1}) ๋࣭ ⭑⚝ "))

treasure_map[treasure_index] = "X"

def play_treasure_hunt():
  print("\n⋆𐙚₊˚⊹♡Harta karun telah disembunyikan! Sekarang giliran pemain menebak⋆𐙚₊˚⊹♡")
  print("⋆𐙚₊˚⊹♡Cobalah untuk menemukan harta karun dengan menebak indeks yang benar⋆𐙚₊˚⊹♡")
  while True:
    print ("\nPeta saat ini: ", ["─୨ৎ─" for _ in range(size)])
    try:
      guess = int(input(f" ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-{size-1}) ๋࣭ ⭑⚝ "))
    except ValueError:
      print("Masukkan angka yang valid!⛇☃︎ ")
      continue

    if guess < 0 or guess >= size:
      print("Indeks tidak valid, pilih antara 0 hingga", size-1)
      continue

    if treasure_map[guess] == "X":
      print(" ⋅˚₊‧ ୨୧ ‧₊˚ ⋅Selamat! Kamu menemukan harta karus di lokasi⋅˚₊‧ ୨୧ ‧₊˚ ⋅ ", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini. Coba lagi!⛇☃︎ ")

  print("Terima kasih sudah bermain!")

play_treasure_hunt()
# Out:
# Selamat datang di Treasure Hunt! ִֶָ𓂃 ࣪˖ ִֶָ🐇་༘࿐
#  ₊˚˖ Masukkan ukuran peta yang diinginkan ₊˚˖ 6
# ⋆. 𐙚 ˚Peta memiliki 6 lokasi (0 hingga 5)⋆. 𐙚 ˚.
#  ๋࣭ ⭑⚝ Masukkan lokasi harta karun (0-5)๋࣭ ⭑⚝ 7
# Lokasi tidak valid. Masukkan angka dalam rentang yang benar⛇☃︎.
#   ๋࣭ ⭑⚝ Masukkan lokasi harta karun (0-5) ๋࣭ ⭑⚝ 3
#
# ⋆𐙚₊˚⊹♡Harta karun telah disembunyikan! Sekarang giliran pemain menebak⋆𐙚₊˚⊹♡
# ⋆𐙚₊˚⊹♡Cobalah untuk menemukan harta karun dengan menebak indeks yang benar⋆𐙚₊˚⊹♡
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
#  ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-5) ๋࣭ ⭑⚝ 6
# Indeks tidak valid, pilih antara 0 hingga 5
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
#  ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-5) ๋࣭ ⭑⚝ 3
#  ⋅˚₊‧ ୨୧ ‧₊˚ ⋅Selamat! Kamu menemukan harta karus di lokasi⋅˚₊‧ ୨୧ ‧₊˚ ⋅  3
# Terima kasih sudah bermain!

# %%
import random
size = 5
print(f"Selamat datang di Treasure Hunt! ִֶָ𓂃 ࣪˖ ִֶָ🐇་༘࿐")

treasure_map = ["─୨ৎ─" for _ in range(size)]

print(f"⋆. 𐙚 ˚Peta memiliki {size} lokasi (0 hingga {size-1})⋆. 𐙚 ˚.")
treasure_index = random.randint(0, size-1)
while treasure_index < 0 or treasure_index >= size:
  print("Lokasi tidak valid. Masukkan angka dalam rentang yang benar⛇☃︎.")
  treasure_index = int(input(f"  ๋࣭ ⭑⚝ Masukkan lokasi harta karun (0-{size-1}) ๋࣭ ⭑⚝ "))

treasure_map[treasure_index] = "X"

def play_treasure_hunt():
  print("\n⋆𐙚₊˚⊹♡Harta karun telah disembunyikan! Sekarang giliran pemain menebak⋆𐙚₊˚⊹♡")
  print("⋆𐙚₊˚⊹♡Cobalah untuk menemukan harta karun dengan menebak indeks yang benar⋆𐙚₊˚⊹♡")
  while True:
    print ("\nPeta saat ini: ", ["─୨ৎ─" for _ in range(size)])
    try:
      guess = int(input(f" ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-{size-1}) ๋࣭ ⭑⚝ "))
    except ValueError:
      print("Masukkan angka yang valid!⛇☃︎ ")
      continue

    if guess < 0 or guess >= size:
      print("Indeks tidak valid, pilih antara 0 hingga", size-1)
      continue

    if treasure_map[guess] == "X":
      print(" ⋅˚₊‧ ୨୧ ‧₊˚ ⋅Selamat! Kamu menemukan harta karus di lokasi⋅˚₊‧ ୨୧ ‧₊˚ ⋅ ", guess)
      break
    else:
      print("Tidak ada harta di lokasi ini. Coba lagi!⛇☃︎ ")

  print("Terima kasih sudah bermain!")

play_treasure_hunt()
# Out:
# Selamat datang di Treasure Hunt! ִֶָ𓂃 ࣪˖ ִֶָ🐇་༘࿐
# ⋆. 𐙚 ˚Peta memiliki 5 lokasi (0 hingga 4)⋆. 𐙚 ˚.
#
# ⋆𐙚₊˚⊹♡Harta karun telah disembunyikan! Sekarang giliran pemain menebak⋆𐙚₊˚⊹♡
# ⋆𐙚₊˚⊹♡Cobalah untuk menemukan harta karun dengan menebak indeks yang benar⋆𐙚₊˚⊹♡
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
#  ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-4) ๋࣭ ⭑⚝ 4
# Tidak ada harta di lokasi ini. Coba lagi!⛇☃︎
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
#  ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-4) ๋࣭ ⭑⚝ 1
# Tidak ada harta di lokasi ini. Coba lagi!⛇☃︎
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
#  ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-4) ๋࣭ ⭑⚝ 2
# Tidak ada harta di lokasi ini. Coba lagi!⛇☃︎
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
#  ๋࣭ ⭑⚝ Masukkan indeks tebakanmu (0-4) ๋࣭ ⭑⚝ 3
# Tidak ada harta di lokasi ini. Coba lagi!⛇☃︎
#
# Peta saat ini:  ['─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─', '─୨ৎ─']
# ...
